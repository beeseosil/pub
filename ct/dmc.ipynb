# %% [markdown]
# ### Clinical Manual Querying
# * py2sas(saspy)를 통해 임상시험 간 발생할 수 있는 query listing을 수행하고자 함
# * 가능한 SAS 및 SAS SQL 래퍼(proc sql)를 사용함

# %% [markdown]
# #### 환경
# * 임상시험 [SAS Datasets (dmisimportant)](https://cafe.naver.com/dmisimportant/104)
# * SAS ODA
# * miniconda, saspy

# %% [markdown]
# #### SAS 세션 연결 및 설정
# * SAS 세션 설정 및 SAS 오브젝트 획득
# * SAS 라이브러리 설정

# %%
import saspy
import pandas as pd

sascfgfile="c:/code/pub/ct/sascfg.py"
sas=saspy.SASsession(cfgfile=sascfgfile)
dbsfile="c:/code/CUBEDEMO2017/spec.xlsx"
dbs=pd.read_excel(dbsfile)
_=sas.submit("""
# %let PATH=/home/u63544628/cubedemo;
libname CUBEDEMO "&PATH.";
""")
# Out:
# Using SAS Config named: oda
# SAS Connection established. Subprocess id is 5108

# %% [markdown]
# #### Dataset 확인
# * 라이브러리가 로드됐는지 확인하기 위함

# %%
datasets={q:sas.sasdata(q,"CUBEDEMO") for q in dbs.DOMAIN.unique()}
_=sas.submit("""
proc sql;
create table FMT as
    select * from DICTIONARY.COLUMNS where libname="CUBEDEMO"
;
run;
""")
fmt=sas.sd2df("FMT")
fmt.dropna(axis=1)
# Out:
#       libname memname memtype     name  type  length   npos  varnum  sortedby  \
# 0    CUBEDEMO      AE    DATA   SUBJID  char    24.0  160.0     1.0       0.0
# 1    CUBEDEMO      AE    DATA    VISIT   num     8.0    0.0     2.0       0.0
# 2    CUBEDEMO      AE    DATA      SEQ   num     8.0    8.0     3.0       0.0
# 3    CUBEDEMO      AE    DATA   AETERM  char   765.0  184.0     4.0       0.0
# 4    CUBEDEMO      AE    DATA  AESTDTC  char    30.0  949.0     5.0       0.0
# ..        ...     ...     ...      ...   ...     ...    ...     ...       ...
# 286  CUBEDEMO      VS    DATA    SYSBP   num     8.0   32.0     7.0       0.0
# 287  CUBEDEMO      VS    DATA    DIABP   num     8.0   40.0     8.0       0.0
# 288  CUBEDEMO      VS    DATA    PULSE   num     8.0   48.0     9.0       0.0
# 289  CUBEDEMO      VS    DATA     RESP   num     8.0   56.0    10.0       0.0
# 290  CUBEDEMO      VS    DATA     TEMP   num     8.0   64.0    11.0       0.0
#
#     xtype notnull  precision transcode
# 0    char      no        0.0       yes
# 1     num      no        0.0       yes
# 2     num      no        0.0       yes
# 3    char      no        0.0       yes
# 4    char      no        0.0       yes
# ..    ...     ...        ...       ...
# 286   num      no        0.0       yes
# 287   num      no        0.0       yes
# 288   num      no        0.0       yes
# 289   num      no        0.0       yes
# 290   num      no        0.0       yes
#
# [291 rows x 13 columns]

# %% [markdown]
# #### SAE Listing
# * SAE Reconciliation을 위한 listing
# * CUBEDEMO 데이터셋에는 **특정 도메인에만 존재하는 USUBJID나 대부분의 값이 null인 row가 있음**
#     * 쿼리 결과에 인덱스나 변수값 대부분이 null인 row가 있을 수 있음

# %%
_=sas.submit("""
data LBLYN;
infile datalines dlm="," dsd;
input CD LBL $50.;
datalines;
1,YES
2,NO
;
run;

data LBLSEX;
infile datalines dlm="," dsd;
input CD SEX $50.;
datalines;
1,MALE
2,FEMALE
;
run;

data LBLOUT;
infile datalines dlm="," dsd;
input CD OUTCOME $50.;
datalines;
1,FATAL
2,NOT RECOVERED/NOT RESOLVED
3,RECOVERED/RESOLVED
4,RECOVERED/RESOLVED WITH SEQUELAE
5,RECOVERING/RESOLVING
6,UNKNOWN
;
run;

data LBLSER;
infile datalines dlm="," dsd;
input CD SAE_CATEGORY $50.;
datalines;
1,NO
2,DEATH
3,HOSPITALIZATION
4,LIFE THREATENING
5,CONGENITAL ANOMALY OR BIRTH DEFECT
6,SIGNIFICANT DISABILITY
7,OTHER MEDICALLY IMPORTANT EVENT
;
run;

data LBLSEV;
infile datalines dlm="," dsd;
input CD SEVERITY $50.;
datalines;
1,MILD
2,MODERATE
3,SEVERE
;
run;

data LBLREL;
infile datalines dlm="," dsd;
input CD RELATIONSHIP $50.;
datalines;
1,NOT RELATED
2,UNLIKELY RELATED
3,POSSIBILY RELATED
4,RELATED
;
run;

data LBLACN;
infile datalines dlm="," dsd;
input CD ACTION_TAKEN $50.;
datalines;
1,DOSE INCREASED
2,DOSE NOT CHANGED
3,DOSE REDUCED
4,DRUG INTERRUPTED
5,DRUG WITHDRAWN
6,NOT APPLICABLE
7,UNKNOWN
;
run;

data IDXDM;
set CUBEDEMO.DM;
drop FERTILE BRTHDTC;
USUBJID=SUBJID;
STUDYID=substr(SUBJID,1,1);
SITEID=substr(SUBJID,find(SUBJID,"-")+1,2);
SUBJID=substr(SUBJID,length(SUBJID)-2,3);
run;

proc sql;
create table SAEL as
select 
USUBJID,STUDYID,SITEID,SUBJID,SEX,AGE,SEQ,AETERM,AESTDTC,AEENDTC,
SEVERITY,RELATIONSHIP,ACTION_TAKEN,OUTCOME,SERIOUS,SAE_CATEGORY
from (
    select IDXDM.USUBJID,IDXDM.STUDYID,IDXDM.SITEID,IDXDM.SUBJID,IDXDM.AGE,
    AE.SEQ,AE.AETERM,AE.AESTDTC,AE.AEENDTC,
    IDXDM.SEX as SEX_,
    AE.AESEV as SEV_,
    AE.AEREL as REL_,
    AE.AEACN as ACN_,
    AE.AEOUT as OUT_,
    AE.AESER as SER_,
    case when (AE.AESER=1 or AE.AESER is null) then "NO" else "YES" end as SERIOUS
    from IDXDM
    right join CUBEDEMO.AE as AE on IDXDM.USUBJID=AE.SUBJID
    )
left join LBLSEX on SEX_=LBLSEX.CD
left join LBLSEV on SEV_=LBLSEV.CD
left join LBLREL on REL_=LBLREL.CD
left join LBLACN on ACN_=LBLACN.CD
left join LBLOUT on OUT_=LBLOUT.CD
left join LBLSER on SER_=LBLSER.CD
order by SITEID,SUBJID
;
run;
""")
sael=sas.sd2df("SAEL").set_index("USUBJID")
sael.head()
# Out:
#          STUDYID SITEID SUBJID     SEX   AGE  SEQ           AETERM  \
# USUBJID
# NaN          NaN    NaN    NaN     NaN   NaN  1.0             TEST
# NaN          NaN    NaN    NaN     NaN   NaN  1.0             asdf
# NaN          NaN    NaN    NaN     NaN   NaN  2.0             Cold
# S-1Z-005       S     1Z    005  FEMALE  33.0  1.0  Limb discomfort
# S-1Z-005       S     1Z    005  FEMALE  33.0  2.0  Angina pectoris
#
#              AESTDTC     AEENDTC SEVERITY      RELATIONSHIP      ACTION_TAKEN  \
# USUBJID
# NaN       2017-02-01  2017-02-16   SEVERE  UNLIKELY RELATED      DOSE REDUCED
# NaN       2017-02-08         NaN      NaN               NaN               NaN
# NaN       2017-02-02  2017-02-14     MILD           RELATED  DRUG INTERRUPTED
# S-1Z-005  2016-02-10  2016-07-02      NaN               NaN    DOSE INCREASED
# S-1Z-005  2016-06-15  2016-06-15      NaN               NaN      DOSE REDUCED
#
#                              OUTCOME SERIOUS      SAE_CATEGORY
# USUBJID
# NaN       NOT RECOVERED/NOT RESOLVED     YES  LIFE THREATENING
# NaN             RECOVERING/RESOLVING      NO               NaN
# NaN                          UNKNOWN     YES             DEATH
# S-1Z-005                       FATAL     YES             DEATH
# S-1Z-005                         NaN      NO               NaN

# %% [markdown]
# #### AE Action Taken이 약물 투여이나 관련 병용약물 없음
# * AE의 AEACNOTH에 따라 CM에 해당 AE indicating 약물이 없는 경우를 확인함

# %%
_=sas.submit("""
proc sql;
create table AECM as
select distinct SUBJID as USUBJID,AETERM,
""||trim(SUBJID)||": having AECM action for AE ("||trim(AETERM)||") without CM" as MSG
from CUBEDEMO.AE as AE
left join (
    select SUBJID as USUBJID,
    substr(CMINDCAE,3) as CMINDCAE,
    CMTRT from CUBEDEMO.CM ) as CM
on (AE.AETERM=CM.CMINDCAE and AE.SUBJID=CM.USUBJID)
where (AE.AEACNOTH in (2,4) and CMINDCAE is null)
order by USUBJID
;
run;
""")
aecm=sas.sd2df("AECM").set_index("USUBJID")
aecm
# Out:
#                                AETERM  \
# USUBJID
# S-1Z-005                       Asthma
# S-1Z-005              Limb discomfort
# S-1Z-005                 Liver damage
# S-1Z-024                      Syncope
# S-1Z-034                    Dizziness
# S-1Z-036              Fatigue extreme
# S-2Z-004                       Nausea
# S-2Z-008                  Astigmatism
# S-2Z-009                     AETEST01
# S-2Z-020                    other SAE
# S-2Z-022        Adverse food reaction
# S-2Z-024                        ASPED
# S-2Z-025                   Head X-ray
# S-2Z-027  Head and eye gaze deviation
# S-2Z-030                   Head X-ray
# S-2Z-030                  Long labour
# S-2Z-033                  Common cold
# S-3Z-004                Tooth abscess
# S-3Z-009                       Anemia
# S-3Z-016             Finger arthritis
# S-3Z-029                       Stroke
# S-3Z-030                       Nausea
# S-3Z-030                Rash pruritic
# S-3Z-036                  Eye allergy
# S-3Z-036           Neck cervicoplasty
# S-4Z-001                          NaN
# S-JP-001                    Numb lips
# S-JP-004              X-ray NOS chest
# S-MJ-011                         test
#
#                                                         MSG
# USUBJID
# S-1Z-005  S-1Z-005: having AECM action for AE (Asthma) w...
# S-1Z-005  S-1Z-005: having AECM action for AE (Limb disc...
# S-1Z-005  S-1Z-005: having AECM action for AE (Liver dam...
# S-1Z-024  S-1Z-024: having AECM action for AE (Syncope) ...
# S-1Z-034  S-1Z-034: having AECM action for AE (Dizziness...
# S-1Z-036  S-1Z-036: having AECM action for AE (Fatigue e...
# S-2Z-004  S-2Z-004: having AECM action for AE (Nausea) w...
# S-2Z-008  S-2Z-008: having AECM action for AE (Astigmati...
# S-2Z-009  S-2Z-009: having AECM action for AE (AETEST01)...
# S-2Z-020  S-2Z-020: having AECM action for AE (other SAE...
# S-2Z-022  S-2Z-022: having AECM action for AE (Adverse f...
# S-2Z-024  S-2Z-024: having AECM action for AE (ASPED) wi...
# S-2Z-025  S-2Z-025: having AECM action for AE (Head X-ra...
# S-2Z-027  S-2Z-027: having AECM action for AE (Head and ...
# S-2Z-030  S-2Z-030: having AECM action for AE (Head X-ra...
# S-2Z-030  S-2Z-030: having AECM action for AE (Long labo...
# S-2Z-033  S-2Z-033: having AECM action for AE (Common co...
# S-3Z-004  S-3Z-004: having AECM action for AE (Tooth abs...
# S-3Z-009  S-3Z-009: having AECM action for AE (Anemia) w...
# S-3Z-016  S-3Z-016: having AECM action for AE (Finger ar...
# S-3Z-029  S-3Z-029: having AECM action for AE (Stroke) w...
# S-3Z-030  S-3Z-030: having AECM action for AE (Nausea) w...
# S-3Z-030  S-3Z-030: having AECM action for AE (Rash prur...
# S-3Z-036  S-3Z-036: having AECM action for AE (Eye aller...
# S-3Z-036  S-3Z-036: having AECM action for AE (Neck cerv...
# S-4Z-001  S-4Z-001: having AECM action for AE ( ) withou...
# S-JP-001  S-JP-001: having AECM action for AE (Numb lips...
# S-JP-004  S-JP-004: having AECM action for AE (X-ray NOS...
# S-MJ-011  S-MJ-011: having AECM action for AE (test) wit...

# %% [markdown]
# #### Concomitant Medication vs. Administration Route
# * 비정형 데이터인 CMTRT에 대해 adm. route가 특이한 경우를 확인함

# %%
_=sas.submit("""
proc sql;
create table CMPO as
select SUBJID as USUBJID,CMTRT,CMROUTE,
""||trim(SUBJID)||": unusual adm. route: "||trim(CMTRT)||": "||trim(CMROUTE)||"" as MSG
from CUBEDEMO.CM
where CMROUTE<>'Oral' and (
CMTRT like '%CAP%' or
CMTRT like '%SC%' or
CMTRT like '%TAB%' or
CMTRT like '%SYR%' or
CMTRT like '%SOLN%')
order by USUBJID
;
""")
cmpo=sas.sd2df("CMPO").set_index("USUBJID")
cmpo
# Out:
#                                          CMTRT        CMROUTE  \
# USUBJID
# S-1Z-007                     DESARTAN TAB 16mg            NaN
# S-1Z-007          ATENOLOL KYEUNG IN TAB 100mg            NaN
# S-1Z-012                     DESARTAN TAB 16mg  Intramuscular
# S-1Z-012                         NEWROSTIN TAB            NaN
# S-1Z-036                             ERDOS CAP           dasd
# S-1Z-037                      ESPROLE TAB 20mg            NaN
# S-2Z-003                      KANGJUNGBING TAB  Intramuscular
# S-2Z-005                          ROUTINES TAB        Topical
# S-2Z-005                          ROUTINES TAB    Intravenous
# S-2Z-020                  TYLENOL ER TAB 325mg  Intramuscular
# S-2Z-021                   VENTOLIN SYR 480mcg    Intravenous
# S-2Z-025                            MAGWELL SC  Intramuscular
# S-2Z-025                           NEZOTIN TAB    Intravenous
# S-2Z-027                      LODOPIN TAB 25mg  Intramuscular
# S-2Z-027                           NEZOTIN TAB    Intravenous
# S-2Z-027                     XALKORI CAP 200mg        Topical
# S-2Z-027                        LITEC COMP CAP    Intravenous
# S-2Z-029                        LITEC COMP SYR        Topical
# S-2Z-029               GRIMEFOL SR TAB 2/500mg    Intravenous
# S-2Z-030                          GRANGZEO TAB    Intravenous
# S-2Z-030                           NEZOTIN TAB  Intramuscular
# S-2Z-030             NESP PREFILLED SYRINGE 10    Intravenous
# S-2Z-030                           RAITECK TAB    Intravenous
# S-2Z-034                     AMOCTIN TAB 375mg        Topical
# S-2Z-038                          GERLANON TAB            NaN
# S-2Z-038                             KANAID SC            NaN
# S-2Z-038                          GERLANON TAB            NaN
# S-3Z-002    WOOHWANG CHUNGSIMWON KYUNGNAM SOLN    Intravenous
# S-3Z-012                 EYEBON W EYEWASH SOLN        Topical
# S-3Z-029              AMLODIPINE KUKJE TAB 5mg            NaN
# S-3Z-036                       PANPYRIN S SOLN  Intramuscular
# S-3Z-040                  TYLENOL ER TAB 650mg            NaN
# S-3Z-040                         GEWORIN I TAB            NaN
# S-JP-001               ASPIRIN DIRECT CHEW TAB            NaN
# S-JP-001                         GEWORIN I TAB            NaN
# S-JP-002         SIMVASTATIN DONGSUNG TAB 20mg            NaN
# S-US-004  GLO ASPIRIN ENTERIC COATED TAB 100mg        Topical
# S1Z010                      ROSURIDIN TAB 10mg            NaN
#
#                                                         MSG
# USUBJID
# S-1Z-007   S-1Z-007: unusual adm. route: DESARTAN TAB 16mg:
# S-1Z-007  S-1Z-007: unusual adm. route: ATENOLOL KYEUNG ...
# S-1Z-012  S-1Z-012: unusual adm. route: DESARTAN TAB 16m...
# S-1Z-012       S-1Z-012: unusual adm. route: NEWROSTIN TAB:
# S-1Z-036      S-1Z-036: unusual adm. route: ERDOS CAP: dasd
# S-1Z-037    S-1Z-037: unusual adm. route: ESPROLE TAB 20mg:
# S-2Z-003  S-2Z-003: unusual adm. route: KANGJUNGBING TAB...
# S-2Z-005  S-2Z-005: unusual adm. route: ROUTINES TAB: To...
# S-2Z-005  S-2Z-005: unusual adm. route: ROUTINES TAB: In...
# S-2Z-020  S-2Z-020: unusual adm. route: TYLENOL ER TAB 3...
# S-2Z-021  S-2Z-021: unusual adm. route: VENTOLIN SYR 480...
# S-2Z-025  S-2Z-025: unusual adm. route: MAGWELL SC: Intr...
# S-2Z-025  S-2Z-025: unusual adm. route: NEZOTIN TAB: Int...
# S-2Z-027  S-2Z-027: unusual adm. route: LODOPIN TAB 25mg...
# S-2Z-027  S-2Z-027: unusual adm. route: NEZOTIN TAB: Int...
# S-2Z-027  S-2Z-027: unusual adm. route: XALKORI CAP 200m...
# S-2Z-027  S-2Z-027: unusual adm. route: LITEC COMP CAP: ...
# S-2Z-029  S-2Z-029: unusual adm. route: LITEC COMP SYR: ...
# S-2Z-029  S-2Z-029: unusual adm. route: GRIMEFOL SR TAB ...
# S-2Z-030  S-2Z-030: unusual adm. route: GRANGZEO TAB: In...
# S-2Z-030  S-2Z-030: unusual adm. route: NEZOTIN TAB: Int...
# S-2Z-030  S-2Z-030: unusual adm. route: NESP PREFILLED S...
# S-2Z-030  S-2Z-030: unusual adm. route: RAITECK TAB: Int...
# S-2Z-034  S-2Z-034: unusual adm. route: AMOCTIN TAB 375m...
# S-2Z-038        S-2Z-038: unusual adm. route: GERLANON TAB:
# S-2Z-038           S-2Z-038: unusual adm. route: KANAID SC:
# S-2Z-038        S-2Z-038: unusual adm. route: GERLANON TAB:
# S-3Z-002  S-3Z-002: unusual adm. route: WOOHWANG CHUNGSI...
# S-3Z-012  S-3Z-012: unusual adm. route: EYEBON W EYEWASH...
# S-3Z-029  S-3Z-029: unusual adm. route: AMLODIPINE KUKJE...
# S-3Z-036  S-3Z-036: unusual adm. route: PANPYRIN S SOLN:...
# S-3Z-040  S-3Z-040: unusual adm. route: TYLENOL ER TAB 6...
# S-3Z-040       S-3Z-040: unusual adm. route: GEWORIN I TAB:
# S-JP-001  S-JP-001: unusual adm. route: ASPIRIN DIRECT C...
# S-JP-001       S-JP-001: unusual adm. route: GEWORIN I TAB:
# S-JP-002  S-JP-002: unusual adm. route: SIMVASTATIN DONG...
# S-US-004  S-US-004: unusual adm. route: GLO ASPIRIN ENTE...
# S1Z010      S1Z010: unusual adm. route: ROSURIDIN TAB 10mg:

# %% [markdown]
# #### CM Administration Deviation per AE Term
# * CM로 대응하는 AE에 대해, 해당 AE가 끝났는데도 대응 CM이 지속 투여되는 것으로 짐작되는 경우
#     * 해당 AE가 CM으로 대응되는 경우 (AEACNOTH in (2,4))
#         * CM이 지속 투여중인데 AE 발현종료일이 있는 경우 (CMONGO==1 and notna(AEENDTC))
#         * CM이 지속 투여중인데 CM 투여종료일이 있는 경우 (CMONGO==1 and notna(CMENDTC))
#         * CM 투여종료일이 AE 발현종료일의 이전인 경우 (CMENDTC > AEENDTC)
# * 결과는 구문적으로 확인이 필요한 경우이며 의미적으로 틀린 경우도 있음
#     * Anxiety Aggravated에 도파민이 투약됨
#     * Death 발현종료일 이후 로수바스타틴이 투약됨
#     * Cold 발현종료일 이후 질정이 투약됨
#     * Eye abcess에 대해 에스시탈로프람이 투약됨

# %%
_=sas.submit("""
proc sql;
create table AECMWD as
select distinct AE.SUBJID as USUBJID,
AE.AETERM,CM.CMINDCAE,CM.CMTRT,
translate(CM.CMENDTC,"01","UK") as CMENDTC,
translate(AE.AEENDTC,"01","UK") as AEENDTC,
CM.CMONGO,
""||trim(AE.SUBJID)||": CM adm. date / status deviates from AE" as MSG
from CUBEDEMO.AE as AE
inner join ( 
	select CM.SUBJID,CM.CMTRT,CM.CMENDTC,CM.CMONGO,
	substr(CM.CMINDCAE,3) as CMINDCAE
	from CUBEDEMO.CM ) as CM
on AE.SUBJID=CM.SUBJID and 
(AE.AETERM is not null and CM.CMINDCAE is not null and AE.AETERM=CM.CMINDCAE)
where AEACNOTH in (2,4) and
(CMONGO=1 and AEENDTC is not null) or
(CMONGO=1 and CMENDTC is not null) or
(CMENDTC > AEENDTC)
order by USUBJID
;
run;
""")
aecmwd=sas.sd2df("AECMWD")
aecmwd.set_index("USUBJID")
# Out:
#                                AETERM                     CMINDCAE  \
# USUBJID
# S-1Z-018            Localized itching            Localized itching
# S-1Z-022           Anxiety aggravated           Anxiety aggravated
# S-1Z-022           Anxiety aggravated           Anxiety aggravated
# S-1Z-026                     Vomiting                     Vomiting
# S-1Z-029                 Drug allergy                 Drug allergy
# S-1Z-032                        Fever                        Fever
# S-1Z-033                        Fever                        Fever
# S-1Z-033                        Fever                        Fever
# S-1Z-033                        Fever                        Fever
# S-1Z-033                        Fever                        Fever
# S-2Z-010             Cerebral abscess             Cerebral abscess
# S-2Z-011                        Cough                        Cough
# S-2Z-017                 Ache stomach                 Ache stomach
# S-2Z-017                 Ache stomach                 Ache stomach
# S-2Z-017                 Ache stomach                 Ache stomach
# S-2Z-017                 Ache stomach                 Ache stomach
# S-2Z-021                   Cell death                   Cell death
# S-2Z-025                     Pain NOS                     Pain NOS
# S-2Z-029                      Head CT                      Head CT
# S-2Z-029                     Headache                     Headache
# S-2Z-030  Hand and foot skin reaction  Hand and foot skin reaction
# S-2Z-035             Cholesterol high             Cholesterol high
# S-2Z-035                  Haemangioma                  Haemangioma
# S-2Z-038              Pain aggravated              Pain aggravated
# S-2Z-038              Pain aggravated              Pain aggravated
# S-3Z-003                   Chickenpox                   Chickenpox
# S-3Z-003                         Cold                         Cold
# S-3Z-003                 Fever chills                 Fever chills
# S-3Z-005  Head and eye gaze deviation  Head and eye gaze deviation
# S-3Z-013                     Ear ache                     Ear ache
# S-3Z-013                  Eye abscess                  Eye abscess
# S-3Z-029                AST increased                AST increased
# S-3Z-035                   Tooth ache                   Tooth ache
# S-4Z-001               AE-5003-AETERM               AE-5003-AETERM
# S-4Z-001                        Death                        Death
# S-US-004                 Headache NOS                 Headache NOS
#
#                                          CMTRT     CMENDTC     AEENDTC  \
# USUBJID
# S-1Z-018                       PLAKON POWD 3mg  2016-12-04  2016-12-02
# S-1Z-022         DOPAMINE DAEWOO INJ 200mg/5ml  2017-02-17         NaN
# S-1Z-022                    XANAX XR TAB 0.5mg  2017-02-02         NaN
# S-1Z-026                          BUSCOPAN TAB  2016-02-10  2016-02-08
# S-1Z-029                     TALLERGY TAB 10mg  2017-02-02  2017-02-01
# S-1Z-032                     TYLENOL TAB 500mg  2016-10-28         NaN
# S-1Z-033                     TYLENOL TAB 500mg  2016-10-28         NaN
# S-1Z-033                     TYLENOL TAB 500mg  2016-10-28  2016-10-21
# S-1Z-033                     TYLENOL TAB 500mg  2017-02-19         NaN
# S-1Z-033                     TYLENOL TAB 500mg  2017-02-19  2016-10-21
# S-2Z-010    KYONGBO CEFAZOLIN SODIUM INJ 250mg  2017-02-07         NaN
# S-2Z-011                        NEVER COLD CAP  2017-02-15  2017-02-14
# S-2Z-017           IBOPROFEN KANGNAM TAB 200mg         NaN  2016-10-07
# S-2Z-017           IBOPROFEN KANGNAM TAB 200mg  2016-09-02         NaN
# S-2Z-017                  TYLENOL ER TAB 650mg         NaN  2016-10-07
# S-2Z-017                  TYLENOL ER TAB 650mg  2016-09-02         NaN
# S-2Z-021                   VENTOLIN SYR 480mcg  2017-02-01         NaN
# S-2Z-025                     MAEKGRONE GRANULE  2017-02-07         NaN
# S-2Z-029               codeine and paracetamol  2017-02-18  2017-02-16
# S-2Z-029               GRIMEFOL SR TAB 2/500mg         NaN  2017-02-15
# S-2Z-030                   KYOUNGBANG OJEOKSAN  2017-02-20  2017-02-15
# S-2Z-035                        flucloxacillin  2017-02-16  2017-02-11
# S-2Z-035                             cefazolin         NaN  2017-02-10
# S-2Z-038                                   NaN  2015-02-14         NaN
# S-2Z-038                             KANAID SC  2015-02-14         NaN
# S-3Z-003                  KAWAI KANYU DROP TAB  2016-02-26  2015-02-27
# S-3Z-003                               가네후랑 질정  2015-02-25  2015-02-20
# S-3Z-003                  TYLENOL ER TAB 325mg  2015-02-06  2015-02-03
# S-3Z-005                            GASKI HWAN         NaN  2017-02-01
# S-3Z-013                           GASPAN POWD         NaN  2017-02-02
# S-3Z-013                      LEXAPRO TAB 15mg  2017-02-01         NaN
# S-3Z-029                         NEWROSTIN TAB         NaN  2016-02-20
# S-3Z-035                  BACCHUS-D CAFFE SOLN         NaN  2017-02-14
# S-4Z-001                    SIMVASTAR TAB 10mg  2017-03-01  2014-03-19
# S-4Z-001                ROSUVAMIBE TAB 10/10mg  2017-03-01  2017-02-01
# S-US-004  GLO ASPIRIN ENTERIC COATED TAB 100mg  2017-03-02  2017-02-03
#
#           CMONGO                                               MSG
# USUBJID
# S-1Z-018     NaN  S-1Z-018: CM adm. date / status deviates from AE
# S-1Z-022     NaN  S-1Z-022: CM adm. date / status deviates from AE
# S-1Z-022     NaN  S-1Z-022: CM adm. date / status deviates from AE
# S-1Z-026     NaN  S-1Z-026: CM adm. date / status deviates from AE
# S-1Z-029     NaN  S-1Z-029: CM adm. date / status deviates from AE
# S-1Z-032     NaN  S-1Z-032: CM adm. date / status deviates from AE
# S-1Z-033     NaN  S-1Z-033: CM adm. date / status deviates from AE
# S-1Z-033     NaN  S-1Z-033: CM adm. date / status deviates from AE
# S-1Z-033     NaN  S-1Z-033: CM adm. date / status deviates from AE
# S-1Z-033     NaN  S-1Z-033: CM adm. date / status deviates from AE
# S-2Z-010     NaN  S-2Z-010: CM adm. date / status deviates from AE
# S-2Z-011     NaN  S-2Z-011: CM adm. date / status deviates from AE
# S-2Z-017     1.0  S-2Z-017: CM adm. date / status deviates from AE
# S-2Z-017     NaN  S-2Z-017: CM adm. date / status deviates from AE
# S-2Z-017     1.0  S-2Z-017: CM adm. date / status deviates from AE
# S-2Z-017     NaN  S-2Z-017: CM adm. date / status deviates from AE
# S-2Z-021     NaN  S-2Z-021: CM adm. date / status deviates from AE
# S-2Z-025     NaN  S-2Z-025: CM adm. date / status deviates from AE
# S-2Z-029     NaN  S-2Z-029: CM adm. date / status deviates from AE
# S-2Z-029     1.0  S-2Z-029: CM adm. date / status deviates from AE
# S-2Z-030     NaN  S-2Z-030: CM adm. date / status deviates from AE
# S-2Z-035     NaN  S-2Z-035: CM adm. date / status deviates from AE
# S-2Z-035     1.0  S-2Z-035: CM adm. date / status deviates from AE
# S-2Z-038     NaN  S-2Z-038: CM adm. date / status deviates from AE
# S-2Z-038     NaN  S-2Z-038: CM adm. date / status deviates from AE
# S-3Z-003     NaN  S-3Z-003: CM adm. date / status deviates from AE
# S-3Z-003     NaN  S-3Z-003: CM adm. date / status deviates from AE
# S-3Z-003     NaN  S-3Z-003: CM adm. date / status deviates from AE
# S-3Z-005     1.0  S-3Z-005: CM adm. date / status deviates from AE
# S-3Z-013     1.0  S-3Z-013: CM adm. date / status deviates from AE
# S-3Z-013     NaN  S-3Z-013: CM adm. date / status deviates from AE
# S-3Z-029     1.0  S-3Z-029: CM adm. date / status deviates from AE
# S-3Z-035     1.0  S-3Z-035: CM adm. date / status deviates from AE
# S-4Z-001     NaN  S-4Z-001: CM adm. date / status deviates from AE
# S-4Z-001     NaN  S-4Z-001: CM adm. date / status deviates from AE
# S-US-004     NaN  S-US-004: CM adm. date / status deviates from AE

# %% [markdown]
# #### Informed Consented Date vs. Baseline Visit Date
# * ICDTC가 Baseline SVDTC보다 최근인 경우를 확인함

# %%
_=sas.submit("""
proc sql;
create table ENSV as
select EN.SUBJID as USUBJID,EN.ICDTC,SV.SVDTC
from CUBEDEMO.EN as EN
left join CUBEDEMO.SV as SV on (EN.SUBJID=SV.SUBJID and SV.VISIT=1)
;
create table ENSV as
select *,""||trim(USUBJID)||": earlier or no visit date: "||trim(ICDTC)||", "||trim(SVDTC)||"" as MSG
from ENSV 
where ICDTC > SVDTC
order by USUBJID
;
run;
""")
ensv=sas.sd2df("ENSV").set_index("USUBJID")
ensv
# Out:
#                ICDTC       SVDTC  \
# USUBJID
# S-1Z-004  2017-02-02         NaN
# S-1Z-008  2017-02-08  2017-02-07
# S-1Z-009  2017-02-07  2017-02-01
# S-1Z-011  2017-02-08  2017-02-01
# S-1Z-012  2017-02-17  2016-02-01
# S-1Z-013  2017-02-05  2017-02-01
# S-2Z-001  2017-02-17  2017-02-01
# S-2Z-026  2017-02-02         NaN
# S-2Z-035  2017-02-03  2017-02-02
# S-3Z-019  2017-02-02  2017-01-16
# S-3Z-022  2017-02-14         NaN
# S-3Z-023  2016-02-14         NaN
# S-3Z-027  2016-02-17  2016-02-14
# S-3Z-038  2017-02-15  2017-02-08
# S-3Z-040  2017-02-16         NaN
# S-3Z-042  2017-02-16  2017-02-07
# S-3Z-043  2017-02-16  2017-02-08
# S-3Z-047  2017-03-01         NaN
# S-3Z-051  2017-06-13  2017-06-01
# S-4Z-001  2017-03-01  2013-09-25
# S-5Z-006  2017-03-20  2017-03-15
# S-5Z-007  2017-03-20  2017-03-15
# S-JP-004  2017-06-01  2017-05-23
# S-MJ-014  2017-06-14  2017-06-04
# S-MJ-015  2017-06-28         NaN
# S-MJ-016  2017-06-28         NaN
# S-MJ-017  2017-06-01         NaN
# S-MJ-018  2017-06-28         NaN
# S-US-008  2017-06-08  2017-06-07
# S1Z001    2017-02-15  2017-02-14
# S1Z002    2017-02-15  2016-12-01
# S1Z004    2016-02-10         NaN
# S1Z006    2017-02-08         NaN
# S1Z008    2017-02-14  2017-02-06
# S1Z010    2017-02-14  2017-02-07
#
#                                                         MSG
# USUBJID
# S-1Z-004    S-1Z-004: earlier or no visit date: 2017-02-02,
# S-1Z-008  S-1Z-008: earlier or no visit date: 2017-02-08...
# S-1Z-009  S-1Z-009: earlier or no visit date: 2017-02-07...
# S-1Z-011  S-1Z-011: earlier or no visit date: 2017-02-08...
# S-1Z-012  S-1Z-012: earlier or no visit date: 2017-02-17...
# S-1Z-013  S-1Z-013: earlier or no visit date: 2017-02-05...
# S-2Z-001  S-2Z-001: earlier or no visit date: 2017-02-17...
# S-2Z-026    S-2Z-026: earlier or no visit date: 2017-02-02,
# S-2Z-035  S-2Z-035: earlier or no visit date: 2017-02-03...
# S-3Z-019  S-3Z-019: earlier or no visit date: 2017-02-02...
# S-3Z-022    S-3Z-022: earlier or no visit date: 2017-02-14,
# S-3Z-023    S-3Z-023: earlier or no visit date: 2016-02-14,
# S-3Z-027  S-3Z-027: earlier or no visit date: 2016-02-17...
# S-3Z-038  S-3Z-038: earlier or no visit date: 2017-02-15...
# S-3Z-040    S-3Z-040: earlier or no visit date: 2017-02-16,
# S-3Z-042  S-3Z-042: earlier or no visit date: 2017-02-16...
# S-3Z-043  S-3Z-043: earlier or no visit date: 2017-02-16...
# S-3Z-047    S-3Z-047: earlier or no visit date: 2017-03-01,
# S-3Z-051  S-3Z-051: earlier or no visit date: 2017-06-13...
# S-4Z-001  S-4Z-001: earlier or no visit date: 2017-03-01...
# S-5Z-006  S-5Z-006: earlier or no visit date: 2017-03-20...
# S-5Z-007  S-5Z-007: earlier or no visit date: 2017-03-20...
# S-JP-004  S-JP-004: earlier or no visit date: 2017-06-01...
# S-MJ-014  S-MJ-014: earlier or no visit date: 2017-06-14...
# S-MJ-015    S-MJ-015: earlier or no visit date: 2017-06-28,
# S-MJ-016    S-MJ-016: earlier or no visit date: 2017-06-28,
# S-MJ-017    S-MJ-017: earlier or no visit date: 2017-06-01,
# S-MJ-018    S-MJ-018: earlier or no visit date: 2017-06-28,
# S-US-008  S-US-008: earlier or no visit date: 2017-06-08...
# S1Z001    S1Z001: earlier or no visit date: 2017-02-15, ...
# S1Z002    S1Z002: earlier or no visit date: 2017-02-15, ...
# S1Z004        S1Z004: earlier or no visit date: 2016-02-10,
# S1Z006        S1Z006: earlier or no visit date: 2017-02-08,
# S1Z008    S1Z008: earlier or no visit date: 2017-02-14, ...
# S1Z010    S1Z010: earlier or no visit date: 2017-02-14, ...

# %% [markdown]
# #### Extraneous Medical History
# * 프로토콜에 180일 이전 병력은 입력하지 않는 것으로 명시됨을 가정, 해당 경우를 확인함

# %%
_=sas.submit("""
proc sql;
create table MHSV as 
    select MH.SUBJID,MH.MHTERM,
    translate(MH.MHENDTC,"01","UK") as MHENDTC,
    SV.SVDTC 
    from CUBEDEMO.MH as MH 
    left join CUBEDEMO.SV as SV
    on MH.SUBJID=SV.SUBJID
    where (SV.VISIT=1 and SV.SVDTC is not null)
    ;
run;

data MHSV;
    set MHSV;
    DTDELTA=input(MHENDTC,yymmdd10.)-input(SVDTC,yymmdd10.);
run;

proc sql;
create table MHSV as 
    select *,""||trim(SUBJID)||": extraneous MH as per protocol: "||put(DTDELTA,8.)||" days" as MSG
	from MHSV 
    where (DTDELTA<=-180 and DTDELTA is not null)
	;
run;
""")
mhsv=sas.sd2df("MHSV").set_index("SUBJID")
mhsv
# Out:
#                               MHTERM     MHENDTC       SVDTC  DTDELTA  \
# SUBJID
# S-1Z-012       Benign tumor of liver  2015-02-04  2016-02-01   -362.0
# S-1Z-030  Hyper HDL cholesterolaemia  2016-01-01  2016-07-21   -202.0
# S-1Z-036             Angina unstable  2016-03-17  2017-03-02   -350.0
# S-2Z-010                   Pneumonia  2016-07-01  2017-01-29   -212.0
# S-2Z-014                 Ache breast  2009-02-03  2016-02-02  -2555.0
# S-2Z-015                Head banging  2012-10-14  2016-03-03  -1236.0
# S-2Z-022                 Ache breast  2016-01-01  2016-08-08   -220.0
# S-2Z-038                Pain biliary  2014-09-14  2015-03-15   -182.0
# S-2Z-038                        Pain  2014-09-15  2015-03-15   -181.0
# S-3Z-003      Dorsal slit of prepuce  2004-02-17  2015-03-04  -4033.0
# S-4Z-001                 MH-1-MHTERM  2007-08-19  2013-09-25  -2229.0
# S-MJ-005        Cerebral haemorrhage  2015-01-01  2016-03-17   -441.0
# S-MJ-008                  Gallstones  2011-04-01  2016-04-06  -1832.0
# S-MJ-019                    Headache  2017-01-01  2017-07-06   -186.0
#
#                                                         MSG
# SUBJID
# S-1Z-012  S-1Z-012: extraneous MH as per protocol:     -...
# S-1Z-030  S-1Z-030: extraneous MH as per protocol:     -...
# S-1Z-036  S-1Z-036: extraneous MH as per protocol:     -...
# S-2Z-010  S-2Z-010: extraneous MH as per protocol:     -...
# S-2Z-014  S-2Z-014: extraneous MH as per protocol:    -2...
# S-2Z-015  S-2Z-015: extraneous MH as per protocol:    -1...
# S-2Z-022  S-2Z-022: extraneous MH as per protocol:     -...
# S-2Z-038  S-2Z-038: extraneous MH as per protocol:     -...
# S-2Z-038  S-2Z-038: extraneous MH as per protocol:     -...
# S-3Z-003  S-3Z-003: extraneous MH as per protocol:    -4...
# S-4Z-001  S-4Z-001: extraneous MH as per protocol:    -2...
# S-MJ-005  S-MJ-005: extraneous MH as per protocol:     -...
# S-MJ-008  S-MJ-008: extraneous MH as per protocol:    -1...
# S-MJ-019  S-MJ-019: extraneous MH as per protocol:     -...

# %%
sas.endsas()
# Out:
# SAS Connection terminated. Subprocess id was 14452

# %% [markdown]
# ### 후기
# * Listing에서 발견되는 의미적 오류를 통해 clinical manual query의 필요성을 알 수 있음
#     * 비정형 데이터와 관련된 문제들: 이상한 적응증의 CM과 administration route 등
# * 구문적 쿼리는 최대한 edit check로 구현해야 함
# * 의미적 쿼리는 가능한 구문적 쿼리에 가깝게 만들어 listing해야 함
#     * Listing 전에 AE, CM, MH 코딩이 이루어져야 함
# * Data Validation Specification의 Query Specification, Manual Query의 내용을 파싱하고 자동화하기
