# %% [markdown]
# ### sas

# %%
import saspy
import pandas as pd
sascfgfile="c:/code/pub/ct/sascfg.py"
sas=saspy.SASsession(cfgfile=sascfgfile)
dbsfile="c:/code/CUBEDEMO2017/spec.xlsx"
dbs=pd.read_excel(dbsfile)
_=sas.submit("""
 libname cubedemo "/home/u63544628/cubedemo";
""")
# Out:
# Using SAS Config named: oda
# SAS Connection established. Subprocess id is 8484

# %%
datasets={q:sas.sasdata(q,"cubedemo") for q in dbs.DOMAIN.unique()}
datasets["EN"].columnInfo()
# Out:
#         Member  Num Variable  Type   Len   Pos
# 0  CUBEDEMO.EN  3.0    ICDTC  Char  30.0  54.0
# 1  CUBEDEMO.EN  1.0   SUBJID  Char  24.0   0.0
# 2  CUBEDEMO.EN  2.0  VERSION  Char  30.0  24.0

# %%
_=sas.submit("""
proc sql;
create table ENSV as
    select EN.SUBJID,EN.ICDTC,SV.SVDTC from CUBEDEMO.EN as EN
    left join CUBEDEMO.SV as SV on EN.SUBJID=SV.SUBJID and SV.VISIT=1
    ;
create table ENSV as
    select *,""||trim(SUBJID)||": earlier or no visit date: "||trim(ICDTC)||", "||trim(SVDTC)||"" as MSG from ENSV 
    where ICDTC > SVDTC
    ;
run;
""")
ensv=sas.sd2df("ENSV")
ensv
# Out:
#       SUBJID       ICDTC       SVDTC  \
# 0   S-1Z-004  2017-02-02         NaN
# 1   S-1Z-008  2017-02-08  2017-02-07
# 2   S-1Z-009  2017-02-07  2017-02-01
# 3   S-1Z-011  2017-02-08  2017-02-01
# 4   S-1Z-012  2017-02-17  2016-02-01
# 5   S-1Z-013  2017-02-05  2017-02-01
# 6   S-2Z-001  2017-02-17  2017-02-01
# 7   S-2Z-026  2017-02-02         NaN
# 8   S-2Z-035  2017-02-03  2017-02-02
# 9   S-3Z-019  2017-02-02  2017-01-16
# 10  S-3Z-022  2017-02-14         NaN
# 11  S-3Z-023  2016-02-14         NaN
# 12  S-3Z-027  2016-02-17  2016-02-14
# 13  S-3Z-038  2017-02-15  2017-02-08
# 14  S-3Z-040  2017-02-16         NaN
# 15  S-3Z-042  2017-02-16  2017-02-07
# 16  S-3Z-043  2017-02-16  2017-02-08
# 17  S-3Z-047  2017-03-01         NaN
# 18  S-3Z-051  2017-06-13  2017-06-01
# 19  S-4Z-001  2017-03-01  2013-09-25
# 20  S-5Z-006  2017-03-20  2017-03-15
# 21  S-5Z-007  2017-03-20  2017-03-15
# 22  S-JP-004  2017-06-01  2017-05-23
# 23  S-MJ-014  2017-06-14  2017-06-04
# ...

# %%
_=sas.submit("""
proc sql;
create table CMPO as 
    select SUBJID,CMTRT,CMROUTE,
    ""||trim(SUBJID)||": unusual administaration route: "||trim(CMTRT)||": "||trim(CMROUTE)||"" as MSG 
    from CUBEDEMO.CM where 
    (CMTRT like "%CAP%" or CMTRT like "%TAB%" or CMTRT like "%SYR%" or CMTRT like "%SOLN%") and 
    CMROUTE<>"Oral"
    ;
run;
""")
cmpo=sas.sd2df("CMPO")
cmpo
# Out:
#       SUBJID                                 CMTRT        CMROUTE  \
# 0   S-1Z-007                     DESARTAN TAB 16mg            NaN
# 1   S-1Z-007          ATENOLOL KYEUNG IN TAB 100mg            NaN
# 2   S-1Z-012                     DESARTAN TAB 16mg  Intramuscular
# 3   S-1Z-012                         NEWROSTIN TAB            NaN
# 4   S-1Z-036                             ERDOS CAP           dasd
# 5   S-1Z-037                      ESPROLE TAB 20mg            NaN
# 6   S-2Z-003                      KANGJUNGBING TAB  Intramuscular
# 7   S-2Z-005                          ROUTINES TAB    Intravenous
# 8   S-2Z-005                          ROUTINES TAB        Topical
# 9   S-2Z-020                  TYLENOL ER TAB 325mg  Intramuscular
# 10  S-2Z-021                   VENTOLIN SYR 480mcg    Intravenous
# 11  S-2Z-025                           NEZOTIN TAB    Intravenous
# 12  S-2Z-027                           NEZOTIN TAB    Intravenous
# ...

# %%
_=sas.submit("""
proc sql;
create table MHSV as 
    select MH.SUBJID,MH.MHTERM,translate(MH.MHENDTC,"01","UK") as MHENDTC,SV.SVDTC from CUBEDEMO.MH as MH 
    left join CUBEDEMO.SV as SV on MH.SUBJID=SV.SUBJID and SV.VISIT=1 and SV.SVDTC is not null
    ;
run;

data MHSV;
    set MHSV;
    DTDELTA=input(MHENDTC,yymmdd10.)-input(SVDTC,yymmdd10.);
run;

proc sql;
create table MHSV as 
    select *,""||trim(SUBJID)||": extraneous MH as per protocol: "||put(DTDELTA,8.)||" days" as MSG
	from MHSV where DTDELTA<=-180 and DTDELTA is not null
	;
run;
""")
mhsv=sas.sd2df("MHSV")
mhsv
# Out:
#       SUBJID                      MHTERM     MHENDTC       SVDTC  DTDELTA  \
# 0   S-1Z-012       Benign tumor of liver  2015-02-04  2016-02-01   -362.0
# 1   S-1Z-030  Hyper HDL cholesterolaemia  2016-01-01  2016-07-21   -202.0
# 2   S-1Z-036             Angina unstable  2016-03-17  2017-03-02   -350.0
# 3   S-2Z-010                   Pneumonia  2016-07-01  2017-01-29   -212.0
# 4   S-2Z-014                 Ache breast  2009-02-03  2016-02-02  -2555.0
# 5   S-2Z-015                Head banging  2012-10-14  2016-03-03  -1236.0
# 6   S-2Z-022                 Ache breast  2016-01-01  2016-08-08   -220.0
# 7   S-2Z-038                Pain biliary  2014-09-14  2015-03-15   -182.0
# 8   S-2Z-038                        Pain  2014-09-15  2015-03-15   -181.0
# 9   S-3Z-003      Dorsal slit of prepuce  2004-02-17  2015-03-04  -4033.0
# 10  S-4Z-001                 MH-1-MHTERM  2007-08-19  2013-09-25  -2229.0
# 11  S-MJ-005        Cerebral haemorrhage  2015-01-01  2016-03-17   -441.0
# ...

# %%
mhdtc.MHENDTC=mhdtc.MHENDTC.apply(lambda q:q.replace("UK","01") if not isinstance(q,float) else q)
mhdtc
# Out:
#        SUBJID                  MHTERM  MHONGO     MHENDTC
# 0    S-1Z-002                 TEST!!!     1.0         NaN
# 1    S-1Z-005    Common cold syndrome     2.0  2016-04-20
# 2    S-1Z-012         Hyperlipidaemia     2.0  2017-02-03
# 3    S-1Z-012   Benign tumor of liver     2.0  2015-02-04
# 4    S-1Z-018       Allergic rhinitis     1.0         NaN
# ..        ...                     ...     ...         ...
# 122  S-MJ-019                Headache     2.0  2017-01-01
# 123  S-US-001  Secondary hypertension     1.0         NaN
# 124  S-US-005       Nausea gravidarum     2.0  2016-02-05
# 125  S-US-006                  Nausea     2.0  2017-03-01
# 126  S-US-007          Aspirin asthma     2.0  2017-03-01
#
# [127 rows x 4 columns]

# %%
mhdtc.replace([][][][][][][][])
# Out:
#   Cell In[37], line 1
#     mhdtc.replace([][][][][][][][])
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
enidx=sas.sd2df("ENIDX")
enidx
# Out:
#        SUBJID       ICDTC
# 0    S-1Z-001  2016-02-15
# 1    S-1Z-002  2017-02-01
# 2    S-1Z-003  2017-02-01
# 3    S-1Z-004  2017-02-02
# 4    S-1Z-005  2016-02-10
# ..        ...         ...
# 180    S1Z006  2017-02-08
# 181    S1Z007  2017-02-08
# 182    S1Z008  2017-02-14
# 183    S1Z009  2017-02-08
# 184    S1Z010  2017-02-14
#
# [185 rows x 2 columns]
