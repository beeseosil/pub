# %% [markdown]
# ## 임상시험 데이터 확인
# ### 목적
# 임상시험 데이터 및 포맷, 스펙(스키마)를 확인하고 임상시험 데이터의 최종적 형태인 sas7bdat / xport를 다룬다.
#
# ### 준비
# 임상시험 데이터: cafe.naver.com/dmisimportant/104

# %% [markdown]
# ### Libraries
# sas7bdat / xport를 열기 위해 sas7bdat 사용

# %%
import os
import numpy as np
import pandas as pd
import secrets
from sas7bdat import SAS7BDAT as sas7bdat

# %% [markdown]
# ### Variables
# CRF 포맷, LAB 데이터 포맷, 데이터셋 파일 경로 설정

# %%
ornament="-"*10
hangul="가나다라마바사아자차카파타하"
ext=(".sas7bdat",".xport")
path_crf="C:/code/CUBEDEMO2017/CUBEDEMO_2017_dc_or_fmt.xlsx"
path_lab="C:/code/CUBEDEMO2017/CUBEDEMO_2017_dc_or_lar.xlsx"
path_set="C:/code/CUBEDEMO2017/SASSET/"

# %% [markdown]
# ### 포맷 파일 로드
# CRF 포맷 파일에서 데이터 도메인 확인

# %%
form_crf=pd.read_excel(path_crf)
form_lab=pd.read_excel(path_lab)
print(ornament,"domain formats:",os.linesep,form_crf.DOMAIN.unique())
# Out:
# ---------- domain formats:
#  ['AE' 'AY' 'CM' 'CT' 'CY' 'DM' 'DS' 'EF' 'EG' 'ES' 'IE' 'IP' 'LB' 'LC'
#  'LY' 'MH' 'MY' 'PD' 'PG' 'RN' 'SU' 'SV' 'VS']

# %% [markdown]
# ### 데이터셋 확인
# 데이터셋 경로의 sas7bdat / xport 파일을 os.path 오브젝트로 로드하고 불량 파일이 있는지 확인

# %%
sasobj=[obj for obj in os.scandir(path_set) if any(map(obj.path.lower().__contains__,ext)) and obj.is_file()]
sasbad=[obj for obj in sasobj if obj.stat().st_size<3]
if len(sasbad)>1:raise Exception("exotic file exists")

# %% [markdown]
# sas7bdat / xport os.path 오브젝트를 도메인 이름: 데이터프레임의 딕셔너리로 로드하고 어떤 도메인의 데이터셋이 있는지 확인
# - 데이터셋 내 string이 bytes이므로 utf-8로 변환하고, 이 과정에서 누락되는 레코드가 있는지도 확인

# %%
def _decode(filepath):
    data=pd.read_sas(filepath)
    nas=data.notna().value_counts().sum()
    bytecol=data.select_dtypes("object").columns
    data[bytecol]=data[bytecol].apply(lambda q:q.str.decode("utf-8"))
    if nas==data.notna().value_counts().sum():
        return data
    else:
        print(ornament,"error:",filepath)
        return None

data={os.path.splitext(obj.name)[0].upper():_decode(obj.path) for obj in sasobj}
print(ornament,"domain:",os.linesep,data.keys(),os.linesep,len(data),"domains")
# Out:
# ---------- domain:
#  dict_keys(['AE', 'AY', 'CM', 'CT', 'CY', 'DA', 'DM', 'DS', 'DY', 'EF', 'EG', 'EN', 'ES', 'IE', 'IP', 'LB', 'LC', 'LY', 'MH', 'MY', 'PD', 'PG', 'RN', 'SN', 'SU', 'SV', 'VS'])
#  27 domains

# %% [markdown]
# ### 도메인별 데이터셋 형태 확인
# SN은 subject 이름, visit site를 포함함을 알 수 있음

# %%
sn=data["SN"]
sn.sample(10)
# Out:
#       SUBJID   VISIT SNNAME       SNDTC
# 25  S-US-003  5007.0   이상하하  2017-03-23
# 20  S-MJ-002  5007.0   김민자가  2017-06-20
# 22  S-MJ-010  3006.0   김민자가  2017-06-14
# 9   S-2Z-028  5007.0   공우카바  2017-02-20
# 17  S-4Z-001  3006.0   원유타가  2017-03-07
# 18  S-4Z-001  5007.0   원유타가  2017-03-07
# 10  S-2Z-029  3006.0   공우카바  2017-02-20
# 13  S-2Z-034  3006.0   송나라사  2017-02-20
# 7   S-2Z-017  5007.0   황태타사  2017-02-21
# 8   S-2Z-023  5007.0   송도파가  2017-02-20

# %% [markdown]
# #### SN: SNNAME 가리기
# Subject 이름을 가림

# %%
def _aname(name,n=2,chars=hangul):
    suffix="".join([secrets.choice(chars) for q in range(n)])
    return name[:n]+suffix

sn_snname_mapper={name:_aname(name) for name in sn.SNNAME.unique()}
sn.SNNAME.replace(sn_snname_mapper,inplace=True)
data["SN"].sample(10)
# Out:
#       SUBJID   VISIT SNNAME       SNDTC
# 24  S-US-002  5007.0   이상하하  2017-03-23
# 21  S-MJ-009  5007.0   김민자가  2017-06-14
# 8   S-2Z-023  5007.0   송도파가  2017-02-20
# 10  S-2Z-029  3006.0   공우카바  2017-02-20
# 18  S-4Z-001  5007.0   원유타가  2017-03-07
# 7   S-2Z-017  5007.0   황태타사  2017-02-21
# 17  S-4Z-001  3006.0   원유타가  2017-03-07
# 5   S-2Z-016  5007.0   황태타사  2017-02-21
# 6   S-2Z-017  3006.0   황태타사  2017-02-21
# 15  S-3Z-013  3006.0   김민자가  2017-03-02

# %% [markdown]
# #### SN: SUBJID 추출
# SN의 SUBJID를 각 도메인의 인덱스로 씀
# - SN.SUBJID 개수를 subject 수로 가정함

# %%
ix=sn.SUBJID.unique()
print(ix)
print(ornament,"total subjects:",len(ix))
# Out:
# ['S-1Z-031' 'S-1Z-034' 'S-2Z-006' 'S-2Z-012' 'S-2Z-013' 'S-2Z-016'
#  'S-2Z-017' 'S-2Z-023' 'S-2Z-028' 'S-2Z-029' 'S-2Z-032' 'S-2Z-034'
#  'S-2Z-035' 'S-3Z-013' 'S-3Z-048' 'S-4Z-001' 'S-MJ-001' 'S-MJ-002'
#  'S-MJ-009' 'S-MJ-010' 'S-US-002' 'S-US-003' 'S-US-007']
# ---------- total subjects: 23

# %% [markdown]
# #### DM: 내용 확인
# DM은 인구학적 정보를 포함하며, 왜인지 인덱스(SN.SUBJID)에 부합하지 않는 row가 많음
# - 인구학적 정보는 시험 초기에 수집되므로 인덱스에 해당하지 않는 row가 있으면 안됨

# %%
dm=data["DM"]
dm
dm[dm.SUBJID.isin(ix)]
# Out:
#        SUBJID  BRTHDTC   AGE  SEX  FERTILE
# 23   S-1Z-031  1984-09  32.0  2.0      1.0
# 26   S-1Z-034  1977-11  38.0  2.0      1.0
# 37   S-2Z-006  1975-04  41.0  2.0      2.0
# 43   S-2Z-012  1977-10  39.0  2.0      1.0
# 44   S-2Z-013  1991-07  25.0  1.0      NaN
# 47   S-2Z-016  1987-02  29.0  1.0      NaN
# 48   S-2Z-017  1983-03  33.0  1.0      NaN
# 54   S-2Z-023  1998-04  17.0  1.0      NaN
# 58   S-2Z-028  1989-04  27.0  2.0      2.0
# 59   S-2Z-029  1975-04  41.0  1.0      NaN
# 62   S-2Z-032  1989-04  27.0  2.0      2.0
# 64   S-2Z-034  1977-04  38.0  1.0      NaN
# 65   S-2Z-035  1977-04  39.0  1.0      NaN
# 83   S-3Z-013  1952-03  63.0  1.0      NaN
# 111  S-3Z-048  1990-10  26.0  1.0      NaN
# 117  S-4Z-001  2011-11  12.0  1.0      1.0
# 133  S-MJ-001  1965-01  51.0  1.0      NaN
# 134  S-MJ-002  1958-03  59.0  1.0      NaN
# 141  S-MJ-009  1952-03  64.0  2.0      2.0
# 142  S-MJ-010  1981-04  34.0  2.0      1.0
# 149  S-US-002  1998-01  19.0  2.0      1.0
# 150  S-US-003  1981-12  35.0  2.0      1.0
# 154  S-US-007  1981-01  36.0  1.0      NaN

# %% [markdown]
# #### AE: 내용 확인
# AE는 시험간 subject 별 adverse effect 정보를 포함
# - 컬럼(e.g. form)별 숫자 코딩된 categorical data가 있음
# - 상기에 따라 MedDRA 코딩된 컬럼이 있음
# - 숫자 코딩의 기준은 CRF Format에 정의되어 있음

# %%
ae=data["AE"]
print(ae.loc[:,[col for col in ae if col.startswith("AE")]].sample(10))
print(ae[ae.SUBJID.isin(ix)][["SUBJID","INV_PT"]].sample(10))
form_crf[form_crf.DOMAIN=="AE"].sample(10)
# Out:
#                           AETERM     AESTDTC  AETEAE  AEOUT     AEENDTC  \
# 63                  Pain burning  2016-06-06     1.0    3.0  2016-07-01
# 61                          Pain  2016-04-25     1.0    2.0         NaN
# 91   Hand and foot skin reaction  2017-02-08     2.0    3.0  2017-02-15
# 48                        Queasy  2017-01-UK     2.0    3.0  2017-02-01
# 180    Myelocyte count decreased  2016-05-19     1.0    6.0         NaN
# 139                AST increased  2016-02-15     2.0    3.0  2016-02-20
# 138                          NaN         NaN     NaN    NaN         NaN
# 149                  Eye allergy  2017-02-02     2.0    5.0         NaN
# 6                Angina pectoris  2016-06-15     1.0    NaN  2016-06-15
# 187              Acute nephritis  2016-07-07     1.0    2.0         NaN
#
#      AESER  AESEV  AEREL  AEACN  AEACNOTH
# 63     1.0    1.0    1.0    2.0       3.0
# 61     3.0    2.0    2.0    2.0       2.0
# 91     3.0    2.0    1.0    2.0       3.0
# 48     1.0    1.0    2.0    4.0       3.0
# 180    3.0    1.0    2.0    2.0       2.0
# 139    1.0    3.0    2.0    5.0       2.0
# 138    NaN    NaN    NaN    5.0       NaN
# 149    7.0    1.0    1.0    5.0       4.0
# 6      NaN    NaN    NaN    3.0       NaN
# 187    3.0    1.0    2.0    5.0       2.0
#        SUBJID                            INV_PT
# 127  S-3Z-013                          Ear pain
# 100  S-2Z-034  Gastrooesophageal reflux disease
# 101  S-2Z-034                         Amblyopia
# 66   S-2Z-017                        Chest pain
# 160  S-4Z-001                               NaN
# 157  S-4Z-001                               NaN
# 158  S-4Z-001                               NaN
# 102  S-2Z-034                   Nasopharyngitis
# 61   S-2Z-016                              Pain
# 185  S-MJ-009                 Diabetes mellitus
#    DOMAIN   FMTNAME   VARNAME  START  END                            LABEL
# 26     AE     AESER     AESER      6    6           Significant disability
# 27     AE     AESER     AESER      7    7  Other medically important event
# 12     AE     AEOUT     AEOUT      2    2       Not recovered/Not resolved
# 13     AE     AEOUT     AEOUT      3    3               Recovered/Resolved
# 2      AE     AEACN     AEACN      3    3                     Dose reduced
# 11     AE     AEOUT     AEOUT      1    1                            Fatal
# 32     AE    AETEAE    AETEAE      2    2                               No
# 0      AE     AEACN     AEACN      1    1                   Dose increased
# 9      AE  AEACNOTH  AEACNOTH      3    3               Non-drug treatment
# 4      AE     AEACN     AEACN      5    5                   Drug withdrawn

# %% [markdown]
# #### AE: AE Code Labeling
# AE의 코딩된 categorical AEs이 CRF 상에서 무엇을 의미하는지 확인하고자 함
# - DB Specification 또는 CRF Format에서 컬럼별 코드 및 라벨을 컬럼: 코드: 라벨의 딕셔너리로 추출
# - 딕셔너리에 따라 컬럼 코드를 라벨링
# - 일견 AESER rate가 상당히 높음

# %%
def _get_label(form,var="VARNAME",kvp=["END","LABEL"]):
    label={}
    for varname in form[var].unique():
        kv=form[form[var]==varname].loc[:,kvp].values
        label[varname]={k:v for k,v in kv}
    return label

ae_label=_get_label(form_crf)
print(ae_label)
# Out:
# {'AEACN': {1: 'Dose increased', 2: 'Dose not changed', 3: 'Dose reduced', 4: 'Drug interrupted', 5: 'Drug withdrawn', 6: 'Not applicable', 7: 'Unknown'}, 'AEACNOTH': {1: 'None', 2: 'Drug treatment', 3: 'Non-drug treatment', 4: 'Drug and non-drug treatment'}, 'AEOUT': {1: 'Fatal', 2: 'Not recovered/Not resolved', 3: 'Recovered/Resolved', 4: 'Recovered/Resolved with sequelae', 5: 'Recovering/Resolving', 6: 'Unknown'}, 'AEREL': {1: 'Not related', 2: 'Unlikely related', 3: 'Possibly related', 4: 'Related'}, 'AESER': {1: 'No', 2: 'Death', 3: 'Hospitalization', 4: 'Life threatening', 5: 'Congenital anomaly or birth defect', 6: 'Significant disability', 7: 'Other medically important event'}, 'AESEV': {1: 'Mild', 2: 'Moderate', 3: 'Severe'}, 'AETEAE': {1: 'Yes', 2: 'No'}, 'AEYN': {1: 'Yes', 2: 'No'}, 'CMINDC': {1: 'Medical history', 2: 'Adverse event', 3: 'Hypertension', 4: 'Prophylaxis', 5: 'Supplement', 6: 'Other'}, 'CMONGO': {1: 'Checked'}, 'CTYN': {1: 'Yes', 2: 'No'}, 'CMYN': {1: 'Yes', 2: 'No'}, 'FERTILE': {1: 'Yes', 2: 'No'}, 'SEX': {1: 'Male', 2: 'Female'}, 'DSDECOD': {1: 'Completed', 2: 'Withdrawal'}, 'DSREAS': {1: 'Failure to meet randomization criteria', 2: 'Withdrawal by subject', 3: 'Lost to follow-up', 4: 'Adverse event', 5: 'Others'}, 'EFHT': {1: 'Yes', 2: 'No'}, 'EFHTGR': {1: 'HI type I', 2: 'HI type II', 3: 'PH type I', 4: 'PH type II'}, 'EFYN': {1: 'Yes', 2: 'No'}, 'EGORRES': {1: 'Normal sinus rhythm', 2: 'Clinically non-significant abnormal sinus rhythm', 3: 'Clinically significant abnormal sinus rhythm'}, 'EGYN': {1: 'Yes', 2: 'No'}, 'ESHT': {1: 'Yes', 2: 'No'}, 'ESHTGR': {1: 'HI type I', 2: 'HI type II', 3: 'PH type I', 4: 'PH type II'}, 'ESYN': {1: 'Yes', 2: 'No'}, 'IEEXYN': {1: 'Yes', 2: 'No'}, 'IEREAS': {1: 'Inclusion/Exclusion criteria not met', 2: 'Subject’s consent withdrawal', 3: 'Other'}, 'IEYN': {1: 'Yes', 2: 'No'}, 'IPYN': {1: 'Yes', 2: 'No'}, 'LBCLSIG': {1: 'NCS', 2: 'CS'}, 'LBNOR': {1: 'Normal', 2: 'Abnormal'}, 'LCYN': {1: 'Yes', 2: 'No'}, 'LBYN': {1: 'Yes', 2: 'No'}, 'MHCONTRT': {1: 'Yes', 2: 'No'}, 'MHONGO': {1: 'Yes', 2: 'No'}, 'MHYN': {1: 'Yes', 2: 'No'}, 'STRATFCT': {1: 'Yes', 2: 'No'}, 'PDAEPI': {1: 'Confirmed'}, 'PDOTH': {1: 'None', 2: 'Low', 3: 'Middle', 4: 'High'}, 'PDPAIN': {1: 'None', 2: 'Low', 3: 'Middle', 4: 'High'}, 'PDRDN': {1: 'None', 2: 'Low', 3: 'Middle', 4: 'High'}, 'PDRZYN': {1: 'Yes', 2: 'No'}, 'PDSJLE': {1: '1'}, 'PDSJLI1': {1: '1'}, 'PDSJLI2': {1: '1'}, 'PDSJLK': {1: '1'}, 'PDSJLL1': {1: '1'}, 'PDSJLL2': {1: '1'}, 'PDSJLM1': {1: '1'}, 'PDSJLM2': {1: '1'}, 'PDSJLR1': {1: '1'}, 'PDSJLR2': {1: '1'}, 'PDSJLS': {1: '1'}, 'PDSJLT1': {1: '1'}, 'PDSJLT2': {1: '1'}, 'PDSJLW': {1: '1'}, 'PDSJRE': {1: '1'}, 'PDSJRI1': {1: '1'}, 'PDSJRI2': {1: '1'}, 'PDSJRK': {1: '1'}, 'PDSJRL1': {1: '1'}, 'PDSJRL2': {1: '1'}, 'PDSJRM1': {1: '1'}, 'PDSJRM2': {1: '1'}, 'PDSJRR1': {1: '1'}, 'PDSJRR2': {1: '1'}, 'PDSJRS': {1: '1'}, 'PDSJRT1': {1: '1'}, 'PDSJRT2': {1: '1'}, 'PDSJRW': {1: '1'}, 'PDST': {1: 'Yes'}, 'PDTJLE': {1: '1'}, 'PDTJLI1': {1: '1'}, 'PDTJLI2': {1: '1'}, 'PDTJLK': {1: '1'}, 'PDTJLL1': {1: '1'}, 'PDTJLL2': {1: '1'}, 'PDTJLM1': {1: '1'}, 'PDTJLM2': {1: '1'}, 'PDTJLR1': {1: '1'}, 'PDTJLR2': {1: '1'}, 'PDTJLS': {1: '1'}, 'PDTJLT1': {1: '1'}, 'PDTJLT2': {1: '1'}, 'PDTJLW': {1: '1'}, 'PDTJRE': {1: '1'}, 'PDTJRI1': {1: '1'}, 'PDTJRI2': {1: '1'}, 'PDTJRK': {1: '1'}, 'PDTJRL1': {1: '1'}, 'PDTJRL2': {1: '1'}, 'PDTJRM1': {1: '1'}, 'PDTJRM2': {1: '1'}, 'PDTJRR1': {1: '1'}, 'PDTJRR2': {1: '1'}, 'PDTJRS': {1: '1'}, 'PDTJRT1': {1: '1'}, 'PDTJRT2': {1: '1'}, 'PDTJRW': {1: '1'}, 'PGORRES': {1: 'Positive', 2: 'Negative'}, 'PGYN': {1: 'Yes', 2: 'No'}, 'RNREAS': {1: 'Inclusion/Exclusion criteria not met', 2: 'Subject’s consent withdrawal', 3: 'Subject lost to follow-up', 4: 'Other'}, 'RNYN': {1: 'Yes', 2: 'No'}, 'ALCOHOL': {1: 'Yes', 2: 'No'}, 'TOBACCO': {1: 'Yes', 2: 'No'}, 'SVNVDES': {1: 'Study completion', 2: 'Early termination'}, 'SVUVREAS': {1: 'Adverse event', 2: 'Others'}, 'VSYN': {1: 'Yes', 2: 'No'}}

# %%
ae_col_ambi=[col for col in ae if col in form_crf[form_crf.DOMAIN=="AE"].VARNAME.values]
ae[ae_col_ambi].replace(ae_label)
# Out:
#     AETEAE                             AEOUT                            AESER  \
# 0      Yes        Not recovered/Not resolved                 Life threatening
# 1      Yes                           Unknown                            Death
# 2      NaN              Recovering/Resolving                              NaN
# 3      Yes                             Fatal                 Life threatening
# 4      Yes  Recovered/Resolved with sequelae                  Hospitalization
# ..     ...                               ...                              ...
# 186     No                           Unknown                               No
# 187    Yes        Not recovered/Not resolved                  Hospitalization
# 188    Yes                             Fatal                               No
# 189     No        Not recovered/Not resolved  Other medically important event
# 190     No                             Fatal                  Hospitalization
#
#         AESEV             AEREL             AEACN                     AEACNOTH
# 0      Severe  Unlikely related      Dose reduced           Non-drug treatment
# 1        Mild           Related  Drug interrupted                         None
# 2         NaN               NaN               NaN                          NaN
# 3    Moderate  Unlikely related  Dose not changed               Drug treatment
# 4    Moderate  Possibly related      Dose reduced               Drug treatment
# ..        ...               ...               ...                          ...
# 186      Mild       Not related  Dose not changed               Drug treatment
# 187      Mild  Unlikely related    Drug withdrawn               Drug treatment
# 188      Mild  Unlikely related           Unknown                         None
# 189      Mild  Possibly related    Drug withdrawn  Drug and non-drug treatment
# 190  Moderate  Unlikely related    Dose increased               Drug treatment
#
# [191 rows x 7 columns]

# %% [markdown]
# #### LB: 내용 확인
# LB는 랩 테스트 결과를 포함
# - VISIT, SEQ 등 랩 테스트 회차에 따른 와이드 포맷으로 되어 있으며, 인덱스를 정할 때 유의해야 함
# - LB.LBTEST에 해당 랩 테스트 명목이 나와 있음
# - LB.LBORRES에 랩 결과 수치가 나와 있음
# - 일부 categorical data 포함 (e.g. Occult Blood)

# %%
lb=data["LB"]
lb.sample(10)
# Out:
#         SUBJID  VISIT   SEQ  \
# 1645  S-2Z-029    7.0   5.0
# 2539  S-4Z-001    1.0  10.0
# 111   S-1Z-018    4.0  19.0
# 1189  S-2Z-014    1.0  15.0
# 847   S-2Z-001    5.0  19.0
# 2165  S-3Z-015    2.0  11.0
# 2294  S-3Z-030    1.0  18.0
# 991   S-2Z-008    2.0  18.0
# 632   S-1Z-033    1.0  18.0
# 736   S-1Z-033    7.0  13.0
#
#                                                  LBTEST   LBORRES  LBNOR  \
# 1645                                         Leukocytes     4.000    1.0
# 2539                                          Bilirubin  9890.035    1.0
# 111                                          Protein[U]       NaN    1.0
# 1189                                Specific Gravity[U]     2.000    2.0
# 847                                          Protein[U]       NaN    1.0
# 2165                                     Hemoglobin A1C     6.000    1.0
# 2294                                    Occult blood[U]       NaN    1.0
# 991                                     Occult blood[U]       NaN    1.0
# 632                                     Occult blood[U]       NaN    1.0
# 736   Glomerular Filtration Rate, Estimated [Automat...   101.480    NaN
#
#       LBCLSIG
# 1645      NaN
# 2539      1.0
# 111       NaN
# 1189      1.0
# 847       NaN
# 2165      NaN
# 2294      NaN
# 991       NaN
# 632       NaN
# 736       NaN

# %%
lb_desc=lb.groupby(["LBTEST"])["LBORRES"].agg(["mean","std","min","max","sum"])
lb_desc
# Out:
#                                                            mean          std  \
# LBTEST
# Alanine Aminotransferase                             336.257126  1409.494132
# Albumin                                              335.514705  1577.394172
# Albumin [U]                                                 NaN          NaN
# Aspartate Aminotransferase                           325.924723  1415.747206
# Bilirubin                                            215.007593  1165.893477
# Creatinine                                           184.471609  1056.242446
# Erythrocytes                                         245.251260  1130.807728
# Glomerular Filtration Rate, Estimated [Automatical  5003.627111  3658.624184
# Glomerular Filtration Rate, Estimated [Automati...    82.635866    40.426010
# Glomerular Filtration Rate, Estimated(Cockcroft...    37.180000    24.580435
# Glomerular Filtration Rate, Estimated(MDRD) [Au...    40.657500    29.612771
# Hematocrit                                           341.115751  1445.115381
# Hemoglobin                                           228.954668  1049.512530
# Hemoglobin A1C                                       209.612806  1006.111026
# Leukocytes                                           283.298689  1413.295060
# Occult blood[U]                                             NaN          NaN
# Platelets                                            556.290862  1420.003208
# Protein                                              260.691800  1342.426188
# Protein[U]                                                  NaN          NaN
# Specific Gravity[U]                                  177.711270   868.078627
# pH[U]                                                275.566368  1280.228214
#
#                                                         min       max  \
# LBTEST
# Alanine Aminotransferase                              0.300  9083.352
# Albumin                                               1.000  9954.012
# Albumin [U]                                             NaN       NaN
# Aspartate Aminotransferase                            1.000  9930.498
# Bilirubin                                             0.400  9890.035
# Creatinine                                            0.377  9596.921
# Erythrocytes                                          1.000  7803.056
# Glomerular Filtration Rate, Estimated [Automatical  782.108  9718.770
# Glomerular Filtration Rate, Estimated [Automati...    0.080   194.760
# Glomerular Filtration Rate, Estimated(Cockcroft...    7.580    66.110
# Glomerular Filtration Rate, Estimated(MDRD) [Au...    5.640    78.070
# Hematocrit                                            1.000  9734.431
# Hemoglobin                                            1.000  9359.996
# Hemoglobin A1C                                        1.000  7777.000
# Leukocytes                                            0.000  9895.650
# Occult blood[U]                                         NaN       NaN
# Platelets                                             1.000  9229.637
# Protein                                               1.000  9451.906
# Protein[U]                                              NaN       NaN
# Specific Gravity[U]                                   0.003  5963.615
# pH[U]                                                 1.000  8688.541
#
#                                                            sum
# LBTEST
# Alanine Aminotransferase                             64225.111
# Albumin                                              63747.794
# Albumin [U]                                              0.000
# Aspartate Aminotransferase                           62251.622
# Bilirubin                                            40636.435
# Creatinine                                           35418.549
# Erythrocytes                                         47088.242
# Glomerular Filtration Rate, Estimated [Automatical   45032.644
# Glomerular Filtration Rate, Estimated [Automati...   14791.820
# Glomerular Filtration Rate, Estimated(Cockcroft...     148.720
# Glomerular Filtration Rate, Estimated(MDRD) [Au...     162.630
# Hematocrit                                           64470.877
# Hemoglobin                                           43501.387
# Hemoglobin A1C                                       40036.046
# Leukocytes                                           53826.751
# Occult blood[U]                                          0.000
# Platelets                                           105138.973
# Protein                                              49531.442
# Protein[U]                                               0.000
# Specific Gravity[U]                                  32876.585
# pH[U]                                                50979.778

# %% [markdown]
# #### LB: Mockup Data 만들기
# Subject Index와 LB를 이용해서 목업 데이터를 만듦
# - SN.SUBJID를 기준으로 피험자당 10번의 랩 테스트를 가정함
# - 편의상 DM 데이터를 결합
# - 연습용 데이터 특성상 생성된 데이터는 현실성이 없음

# %%
def _gen_mockup_value(desc,count):
    print(ornament,"generating values")
    return {q:np.random.normal(desc.loc[q]["mean"],desc.loc[q]["std"],count) for q in desc.index}

def _gen_mockup(desc,ix,count=10):
    data=_gen_mockup_value(desc,count=len(ix)*count)
    ix=pd.MultiIndex.from_product([ix,[q for q in range(1,count+1,1)]],names=["SUBJID","VISIT"])
    return pd.DataFrame(data,ix).reset_index()

_gen_mockup(lb_desc.dropna(),ix).merge(dm,on="SUBJID")
# Out:
# ---------- generating values
#        SUBJID  VISIT  Alanine Aminotransferase      Albumin  \
# 0    S-1Z-031      1               2634.906749   533.524841
# 1    S-1Z-031      2                585.964940   589.470691
# 2    S-1Z-031      3               1978.941811  1763.981715
# 3    S-1Z-031      4                113.117333  1442.474993
# 4    S-1Z-031      5               2964.423192    12.258556
# ..        ...    ...                       ...          ...
# 225  S-US-007      6               1085.833640   540.821357
# 226  S-US-007      7               1670.176291 -1610.486892
# 227  S-US-007      8              -1017.705167  -407.098224
# 228  S-US-007      9                934.931086 -2538.936570
# 229  S-US-007     10               -598.888312  1631.033512
#
#      Aspartate Aminotransferase    Bilirubin   Creatinine  Erythrocytes  \
# 0                   -807.963816   581.388932   600.952135    307.588939
# 1                   1288.162267  -708.573748   331.210101   -390.085265
# 2                    990.436783 -1859.405020   -76.395511   1773.971259
# 3                    701.951166    13.758323  1483.851713   1795.280339
# 4                    348.837296   626.683202  1045.188406   -278.564498
# ..                          ...          ...          ...           ...
# 225                 1845.934935   337.118280  1215.720402    898.997978
# 226                 1424.355967  1961.262145  -832.380560  -1630.307754
# 227                -1696.560014   930.426466   253.735864   1975.833521
# 228                 1237.135469  1707.916614  1340.341660   1492.285400
# 229                  751.226779  1611.782433   500.274394    681.888745
#
#      Glomerular Filtration Rate, Estimated [Automatical  \
# 0                                          5258.337568
# 1                                          2817.400402
# 2                                          4437.979050
# 3                                          5701.201243
# 4                                          8430.552700
# ..                                                 ...
# 225                                        5827.504782
# 226                                        6611.334649
# 227                                        2692.734394
# 228                                        6094.005395
# 229                                        5974.822200
#
#      Glomerular Filtration Rate, Estimated [Automatically calculated]  ...  \
# 0                                           116.928805                 ...
# 1                                            93.646661                 ...
# 2                                            59.455479                 ...
# 3                                            80.334033                 ...
# 4                                            72.918841                 ...
# ..                                                 ...                 ...
# 225                                          63.854711                 ...
# 226                                          92.701876                 ...
# 227                                         109.756303                 ...
# 228                                          93.938583                 ...
# 229                                          50.721436                 ...
#
#      Hemoglobin A1C   Leukocytes    Platelets      Protein  \
# 0        -64.347504   566.909566  -912.762652 -1998.905348
# 1       -976.113950  2166.951034    13.138443  -872.764852
# 2      -1656.555055  -213.669048  -121.663959  1296.157977
# 3      -1144.280670  2162.004948  1396.519662   -73.279230
# 4        219.762879  1218.186209   -52.471319 -1590.563299
# ..              ...          ...          ...          ...
# 225     -848.287788  -479.607242  -986.737467   552.246911
# 226     -458.145699  2449.700574 -1162.663616 -1975.669533
# 227      249.038567 -1175.578979  -422.345580 -1681.781566
# 228     1674.741847   585.353918   554.552963   717.357028
# 229     -510.547487   897.343417   966.514553  1484.302522
#
#      Specific Gravity[U]        pH[U]  BRTHDTC   AGE  SEX  FERTILE
# 0             819.406213   796.693771  1984-09  32.0  2.0      1.0
# 1            -897.257543  1306.041228  1984-09  32.0  2.0      1.0
# 2             278.837654   791.844183  1984-09  32.0  2.0      1.0
# 3           -1448.939978  2278.581153  1984-09  32.0  2.0      1.0
# 4             834.667785  -730.636529  1984-09  32.0  2.0      1.0
# ..                   ...          ...      ...   ...  ...      ...
# 225          -446.053852  -312.836843  1981-01  36.0  1.0      NaN
# 226          1073.546004  -931.718494  1981-01  36.0  1.0      NaN
# 227            28.118825  2115.800956  1981-01  36.0  1.0      NaN
# 228           -59.794714  -153.469840  1981-01  36.0  1.0      NaN
# 229          -815.267927  -219.226333  1981-01  36.0  1.0      NaN
#
# [230 rows x 24 columns]

# %% [markdown]
# ### 후기
# - 하나의 임상시험을 구성하는 데이터셋은 많으며, 각 데이터 연동을 위한 정의와 연동이 일목요연히 되어 있음
#     - 수치형, 범주형 값이 혼재함
#     - 일반적이지 않은 범주형 값 (0,1 No,Yes(False,True)가 아닌 1,2 Yes,No)
#     - 데이터셋 복잡도의 중요한 요인은 프로토콜의 site visit number로 생각됨
# - 분석에 이용되는 실질적 데이터뿐만 아니라 엔드유저에게 해당 데이터가 어떻게 보이고 수집됐는지를 포함
# - 프로토콜 이해를 선행하지 않고서는 정확하고 효율적으로 데이터셋을 다루기 어려움
# - 도메인 데이터와 DB Specification 내 각 도메인 정의를 연동할 수 있는 클래스 이용 필요
